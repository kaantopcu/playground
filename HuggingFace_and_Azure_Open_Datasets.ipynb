# %% [markdown]
# <a href="https://colab.research.google.com/github/kaantopcu/playground/blob/main/HuggingFace_and_Azure_Open_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#     Load a dataset from Hugging Face and analyze it
#
#     Load a dataset from Azure Open Datasets
#
#     Build a classifier with Hugging Face Transformers

# %% [markdown]
# # Azure Open Datasets

# %%
try:
    import azureml.opendatasets as opendatasets
    print("azureml-opendatasets installed successfully")
except ImportError:
    try:
        import pip
        pip.main(['install', 'azureml'])
        pip.main(['install', 'azureml.opendatasets'])
        import azureml.opendatasets as opendatasets
        print("azureml-opendatasets installed successfully")
    except Exception as e:
        print(f"An error occurred during installation: {e}")
# Out:
# azureml-opendatasets installed successfully

# %%
from azureml.opendatasets import PublicHolidays
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
end_date = datetime.today()
start_date = datetime.today() - relativedelta(months=3)
hol = PublicHolidays(start_date=start_date, end_date=end_date)
hol_df = hol.to_pandas_dataframe()
hol_df
# Out:
# {'infer_column_types': 'False', 'activity': 'download'}
# {'infer_column_types': 'False', 'activity': 'download', 'activityApp': 'FileDataset'}
# [Info] read from /tmp/tmpl7anoh61/https%3A/%2Fazureopendatastorage.azurefd.net/holidaydatacontainer/Processed/part-00000-tid-8468414522853579044-35925ba8-a227-4b80-9c89-17065e7bf1db-649-c000.snappy.parquet
#       countryOrRegion         holidayName normalizeHolidayName isPaidTimeOff  \
# 28253          Norway              Søndag               Søndag          None
# 28254          Sweden              Söndag               Söndag          None
# 28255          Norway              Søndag               Søndag          None
# 28256          Sweden              Söndag               Söndag          None
# 28257         Belarus         День женщин          День женщин          None
# ...               ...                 ...                  ...           ...
# 28436         Germany       Pfingstmontag        Pfingstmontag          None
# 28437         Hungary        Pünkösdhétfő         Pünkösdhétfő          None
# 28438     Netherlands  Tweede Pinksterdag   Tweede Pinksterdag          None
# 28439          Norway      Andre pinsedag       Andre pinsedag          None
# 28440     Switzerland       Pfingstmontag        Pfingstmontag          None
#
#       countryRegionCode       date
# 28253                NO 2024-02-25
# 28254                SE 2024-02-25
# 28255                NO 2024-03-03
# 28256                SE 2024-03-03
# 28257                BY 2024-03-08
# ...                 ...        ...
# 28436                DE 2024-05-20
# 28437                HU 2024-05-20
# 28438                NL 2024-05-20
# 28439                NO 2024-05-20
# 28440                CH 2024-05-20
#
# [188 rows x 6 columns]
